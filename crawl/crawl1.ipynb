# %%
# 크롤링 라이브러리
# requests, BeautipleSoup, Selenium, scrapy....

# 파이썬 라이브러리 사용할 수도 있으나 외부 라이브러리를 주로 사용함

# requests: 특정 url에서 정보를 가져오기 쉽게 도와주는 라이브러리

# %%
import requests

urls = ["https://www.python.org/","https://www.naver.com/"]

name = "robots.txt"

for url in urls:
    print(url+name)
    robots = requests.get(url+name)
    print(robots.text)
# Out:
# https://www.python.org/robots.txt
# # Directions for robots.  See this URL:
# # http://www.robotstxt.org/robotstxt.html
# # for a description of the file format.
#
# User-agent: HTTrack
# User-agent: puf
# User-agent: MSIECrawler
# Disallow: /
#
# # The Krugle web crawler (though based on Nutch) is OK.
# User-agent: Krugle
# Allow: /
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# # No one should be crawling us with Nutch.
# User-agent: Nutch
# Disallow: /
#
# # Hide old versions of the documentation and various large sets of files.
# User-agent: *
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# https://www.naver.com/robots.txt
# User-agent: *
# Disallow: /
# Allow : /$

# %%
import urllib.request as req

url = "https://google.com"

save_file = "./google.html"

try:
    file1, header1 = req.urlretrieve(url, save_file)
except Exception as e:
    print(e)
else:
    print(header1)
    print(file1)
    print("성공")
# Out:
# Date: Thu, 06 Jul 2023 07:18:19 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# Content-Security-Policy-Report-Only: object-src 'none';base-uri 'self';script-src 'nonce-1_V4H8FdeN3ogLXc0dlraA' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: 1P_JAR=2023-07-06-07; expires=Sat, 05-Aug-2023 07:18:19 GMT; path=/; domain=.google.com; Secure
# Set-Cookie: AEC=Ad49MVGJ3l6Tr3TDac7k-vULnU6g90pKGv0oFlcbjMl7GdVR7mkOO4ulPQ; expires=Tue, 02-Jan-2024 07:18:19 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax
# Set-Cookie: NID=511=KrmTEIL0w6pTHXJBmpoIqgZVUKmSX7Nt2hLDCDO4yKHSt7lPqAIIE4nTrwp-5PRKx3ECphU4kMtYJV4Ma4MX9o1TNe8Fuww_A6fLZPU2fKxIjc4BW3KffBqzPdZTO03rXZhOmXj6zxu3H_oVsJAaubb1cq83aaat3TvHxAWgb3E; expires=Fri, 05-Jan-2024 07:18:19 GMT; path=/; domain=.google.com; HttpOnly
# Alt-Svc: h3=":443"; ma=2592000,h3-29=":443"; ma=2592000
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close
# Transfer-Encoding: chunked
#
#
# ./google.html
# 성공

# %% [markdown]
# # urlretrieve
#   - 요청하는 url의 정보를 로컬 파일로 저장
#   - 튜플로 반환됨
#   - csv, api 데이터 등 많은 양의 데이터를 한번에 저장할 때 사용

# %%
img_url = "data:image/jpeg;base64,..."

html_url = "https://www.google.com"

# 경로
img_path = "./dog.jpg"
html_path = "./google.html"

try:
    file1, header1 = req.urlretrieve(img_url, img_path)
    file2, header2 = req.urlretrieve(html_url, html_path)
except Exception as e:
    print(e)
else:
    print("file1 {}".format(file1))
    print("file2 {}".format(file2))
# Out:
# file1 ./dog.jpg
# file2 ./google.html

# %% [markdown]
# ##### 다운로드는 필요없고 내용만 분석하고 싶을 때
#     - open(), read()

# %%
weather_url = "http://devweather.kma.go.kr/wid/queryDFSRSS.jsp?zone=1159060500"

data = req.urlopen(weather_url).read()

text = data.decode("utf-8")

print(text)
# Out:
# <?xml version="1.0" encoding="UTF-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 동네예보 웹서비스 - 서울특별시 동작구 흑석동 도표예보</title>
# <link>http://www.kma.go.kr/weather/main.jsp</link>
# <description>동네예보 웹서비스</description>
# <language>ko</language>
# <generator>동네예보</generator>
# <pubDate>2023년 07월 06일 (목)요일 14:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>서울특별시 동작구 흑석동</category>
# <title>동네예보(도표) : 서울특별시 동작구 흑석동 [X=60,Y=125]</title><link>http://www.kma.go.kr/weather/forecast/timeseries.jsp?searchType=INTEREST&amp;dongCode=1159060500</link>
# <guid>http://www.kma.go.kr/weather/forecast/timeseries.jsp?searchType=INTEREST&amp;dongCode=1159060500</guid>
# <description>
#  <header>
#   <tm>202307061400</tm>
#   <ts>4</ts>
#   <x>60</x>
#   <y>125</y>
#  </header>
#  <body>
#   <data seq="0">
#    <hour>18</hour>
#    <day>0</day>
#    <temp>30.0</temp>
#    <tmx>-999.0</tmx>
#    <tmn>-999.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>3.1</ws>
#    <wd>5</wd>
#    <wdKor>남서</wdKor>
#    <wdEn>SW</wdEn>
#    <reh>65</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="1">
#    <hour>21</hour>
#    <day>0</day>
#    <temp>27.0</temp>
#    <tmx>-999.0</tmx>
#    <tmn>-999.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.3</ws>
#    <wd>4</wd>
#    <wdKor>남</wdKor>
#    <wdEn>S</wdEn>
#    <reh>80</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="2">
#    <hour>24</hour>
#    <day>0</day>
#    <temp>25.0</temp>
#    <tmx>-999.0</tmx>
#    <tmn>-999.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.2000000000000002</ws>
#    <wd>4</wd>
#    <wdKor>남</wdKor>
#    <wdEn>S</wdEn>
#    <reh>85</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="3">
#    <hour>3</hour>
#    <day>1</day>
#    <temp>24.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>3</sky>
#    <pty>0</pty>
#    <wfKor>구름 많음</wfKor>
#    <wfEn>Mostly Cloudy</wfEn>
#    <pop>20</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.4000000000000001</ws>
#    <wd>3</wd>
#    <wdKor>남동</wdKor>
#    <wdEn>SE</wdEn>
#    <reh>85</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="4">
#    <hour>6</hour>
#    <day>1</day>
#    <temp>23.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>4</sky>
#    <pty>0</pty>
#    <wfKor>흐림</wfKor>
#    <wfEn>Cloudy</wfEn>
#    <pop>30</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.3</ws>
#    <wd>3</wd>
#    <wdKor>남동</wdKor>
#    <wdEn>SE</wdEn>
#    <reh>90</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="5">
#    <hour>9</hour>
#    <day>1</day>
#    <temp>27.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>4</sky>
#    <pty>0</pty>
#    <wfKor>흐림</wfKor>
#    <wfEn>Cloudy</wfEn>
#    <pop>30</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>2.6</ws>
#    <wd>4</wd>
#    <wdKor>남</wdKor>
#    <wdEn>S</wdEn>
#    <reh>75</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="6">
#    <hour>12</hour>
#    <day>1</day>
#    <temp>31.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>10</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>2.7</ws>
#    <wd>4</wd>
#    <wdKor>남</wdKor>
#    <wdEn>S</wdEn>
#    <reh>55</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="7">
#    <hour>15</hour>
#    <day>1</day>
#    <temp>31.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>3.3000000000000003</ws>
#    <wd>3</wd>
#    <wdKor>남동</wdKor>
#    <wdEn>SE</wdEn>
#    <reh>50</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="8">
#    <hour>18</hour>
#    <day>1</day>
#    <temp>30.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>3.3000000000000003</ws>
#    <wd>3</wd>
#    <wdKor>남동</wdKor>
#    <wdEn>SE</wdEn>
#    <reh>55</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="9">
#    <hour>21</hour>
#    <day>1</day>
#    <temp>27.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.6</ws>
#    <wd>3</wd>
#    <wdKor>남동</wdKor>
#    <wdEn>SE</wdEn>
#    <reh>65</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="10">
#    <hour>24</hour>
#    <day>1</day>
#    <temp>25.0</temp>
#    <tmx>32.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.7000000000000002</ws>
#    <wd>2</wd>
#    <wdKor>동</wdKor>
#    <wdEn>E</wdEn>
#    <reh>70</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="11">
#    <hour>3</hour>
#    <day>2</day>
#    <temp>24.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.5</ws>
#    <wd>2</wd>
#    <wdKor>동</wdKor>
#    <wdEn>E</wdEn>
#    <reh>75</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="12">
#    <hour>6</hour>
#    <day>2</day>
#    <temp>24.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.5</ws>
#    <wd>2</wd>
#    <wdKor>동</wdKor>
#    <wdEn>E</wdEn>
#    <reh>80</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="13">
#    <hour>9</hour>
#    <day>2</day>
#    <temp>27.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>0</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>2.6</ws>
#    <wd>3</wd>
#    <wdKor>남동</wdKor>
#    <wdEn>SE</wdEn>
#    <reh>70</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="14">
#    <hour>12</hour>
#    <day>2</day>
#    <temp>28.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>1</sky>
#    <pty>0</pty>
#    <wfKor>맑음</wfKor>
#    <wfEn>Clear</wfEn>
#    <pop>10</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>2.0</ws>
#    <wd>3</wd>
#    <wdKor>남동</wdKor>
#    <wdEn>SE</wdEn>
#    <reh>70</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="15">
#    <hour>15</hour>
#    <day>2</day>
#    <temp>30.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>3</sky>
#    <pty>0</pty>
#    <wfKor>구름 많음</wfKor>
#    <wfEn>Mostly Cloudy</wfEn>
#    <pop>20</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.3</ws>
#    <wd>4</wd>
#    <wdKor>남</wdKor>
#    <wdEn>S</wdEn>
#    <reh>65</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="16">
#    <hour>18</hour>
#    <day>2</day>
#    <temp>29.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>3</sky>
#    <pty>0</pty>
#    <wfKor>구름 많음</wfKor>
#    <wfEn>Mostly Cloudy</wfEn>
#    <pop>20</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.2000000000000002</ws>
#    <wd>6</wd>
#    <wdKor>서</wdKor>
#    <wdEn>W</wdEn>
#    <reh>70</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="17">
#    <hour>21</hour>
#    <day>2</day>
#    <temp>27.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>4</sky>
#    <pty>0</pty>
#    <wfKor>흐림</wfKor>
#    <wfEn>Cloudy</wfEn>
#    <pop>30</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>1.2000000000000002</ws>
#    <wd>6</wd>
#    <wdKor>서</wdKor>
#    <wdEn>W</wdEn>
#    <reh>80</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#   <data seq="18">
#    <hour>24</hour>
#    <day>2</day>
#    <temp>26.0</temp>
#    <tmx>31.0</tmx>
#    <tmn>23.0</tmn>
#    <sky>4</sky>
#    <pty>0</pty>
#    <wfKor>흐림</wfKor>
#    <wfEn>Cloudy</wfEn>
#    <pop>30</pop>
#    <r12>0.0</r12>
#    <s12>0.0</s12>
#    <ws>0.5</ws>
#    <wd>4</wd>
#    <wdKor>남</wdKor>
#    <wdEn>S</wdEn>
#    <reh>85</reh>
#    <r06>0.0</r06>
#    <s06>0.0</s06>
#   </data>
#  </body>
# </description>
# </item>
# </channel>
# </rss>

# %%
url = "https://www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"

try:
    res = req.urlopen(url)
    contents = res.read().decode('euc-kr')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# Date: Thu, 06 Jul 2023 07:57:02 GMT
# Content-Type: text/html;charset=EUC-KR
# Set-Cookie: JSESSIONID=038399D00D5E508DE87EFAF132A853C7.Tomcat; Path=/; HttpOnly
# Vary: Accept-Encoding,User-Agent
# Access-Control-Allow-Credentials: true
# Transfer-Encoding: chunked
# Connection: close
# Server: Apache
#
#
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
#
#
#
# <html lang="ko">
# <head>
#
# <title>11번가 베스트 | 11번가</title>
# <meta name="Title" content="11번가 베스트 | 11번가">
# <meta name="Description" content=" 베스트! 다른 사람들은 지금 뭘 살까? 11번가 추천하는 실시간  베스트 아이템 순위!">
# <meta name="Keywords" content=" | 11번가">
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <link rel="canonical" href="//www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"/><link rel="alternate" media="only screen and (max-width: 640px)" href="//m.11st.co.kr/page/main/rank"/>
#
#
#
# <script type="text/javascript" src="//c.011st.com/html/experiment/experimentMetaInfo.js"></script>
#
# <script type="text/javascript" src="//c.011st.com/js/plab/plab-web-sdk-0.9.1.min.js"></script>
#
# <script>
#
#     var plabPageKey = '/best200/category';
#     try{
#
#         var params = {
#             projectKey : "11st_web",
#             domain : "11st.co.kr"
#         };
#         plab.initBy(params, experimentMetaInfo);
#
#     }catch (e) { console.log(e) };
#
#
# </script>
#
# <script type="text/javascript">
# 	!function(f,b,e,v,n,t,s) {if(f.fbq)return;n=f.fbq=function(){n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}; if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0'; n.queue=[];t=b.createElement(e);t.async=!0; t.src=v;s=b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t,s)}(window, document,'script', 'https://connect.facebook.net/en_US/fbevents.js');
# 	try {
# 		fbq('init', '2299486926950990');
# 		fbq('track', 'PageView');
# 	} catch (e) {
# 		console.error(e);
# 	}
# </script>
# <noscript>
# 	<img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=2299486926950990&ev=PageView&noscript=1"/>
# </noscript>
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-876562370"></script>
# <script>
# 	try{
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
# 		gtag('config', 'AW-876562370');
# 	} catch(e) {}
# </script>
#
#
# <script type="text/javascript">
#
#
# 	// Global Var
# 	var _IMG_PATH_  = "//s.011st.com";
# 	var _UPLOAD_IMG_PATH_  = "http://image.11st.co.kr";
# 	var _SSL_UPLOAD_IMG_PATH_ = "https://www.11st.co.kr/is";
# 	var _ACTION_CONTEXT_  = "";
# 	var _FILE_UPLOAD_PATH_ = "http://image.11st.co.kr";
# 	var _GNB_CONTEXT_PATH_ = "//www.11st.co.kr";
# 	var _ACTION_CONTEXT_URL_ = "http://www.11st.co.kr";
# 	var _SSL_ACTION_CONTEXT_URL_ = "https://www.11st.co.kr";
# 	var _SSL_IMG_PATH_ = "//s.011st.com";
# 	var _GLOBAL_CONTEXT_PATH_ = "http://globalshopping.11st.co.kr";
# 	var _BEAUTY_CONTEXT_PATH_ = "http://beauty.11st.co.kr";
# 	var _SOHO_CONTEXT_PATH_ = "http://soho.11st.co.kr";
# 	var _JS_PATH_ = "//c.011st.com";
# 	var _SSL_JS_PATH_ = "//c.011st.com";
#
# 	var _GNB_LOGIN_URL_ = "https://login.11st.co.kr/login/Login.tmall";
# 	var _GNB_LOGOUT_URL_ = "https://login.11st.co.kr/login/Logout.tmall";
# 	var _PRODUCT_DETAIL_URL_ = "https://www.11st.co.kr/product/SellerProductDetail.tmall?method=getSellerProductDetail&prdNo=";
#
# 	var _ENJOY_SEARCH_VAR_ = "NONE";
# 	var _ENJOY_SEARCH_KEY_YN_ = "N";
#
# 	var _SELLER_SHOP_DOMAIN_ = "https://shop.11st.co.kr";
#
# 	// 변경 권고
# 	var _CSS_URL_			= "//c.011st.com";
# 	var _SSL_CSS_URL_		= "//c.011st.com";
# 	var _IMG_URL_			= "//s.011st.com";
# 	var _SSL_IMG_URL_		= "//s.011st.com";
# 	var _UPLOAD_URL_		= "http://i.011st.com";
# 	var _SSL_UPLOAD_URL_	= "https://i.011st.com";
#
# 	var _LOGIN_TARGET_URL_ 	= "https://login.11st.co.kr";
#
# 	// TZONE Var
# 	var _TZONE_URL_			= "http://skt.11st.co.kr";
# 	var _TZONE_URL_HOME_	= "http://skt.11st.co.kr/html/tzone/tZoneMain.html";
# 	var _SELLER_URL_		= "http://seller.11st.co.kr";
# 	var _SOFFICE_URL_		= "http://soffice.11st.co.kr";
# 	var _DS_URL_			= "http://ds.11st.co.kr";
# 	var _MY11ST_URL_		= "http://buy.11st.co.kr/order/myTmall.tmall?method=getMyTmallMain";
# 	var _SHOPPINGCART_URL_ 	= "http://buy.11st.co.kr/cart/CartAction.tmall?method=getCartList";
# 	var _MYSELL_U

# %%
# 네이버 뉴스 가져오기
news_url = "https://sports.news.naver.com/news?oid=311&aid=0001612891"

try:
    res = req.urlopen(news_url)
    contents = res.read().decode('utf-8')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# date: Thu, 06 Jul 2023 08:04:32 GMT
# content-type: text/html;charset=UTF-8
# transfer-encoding: chunked
# x-xss-protection: 1; mode=block
# strict-transport-security: max-age=31536000
# cache-control: no-store
# content-language: ko
# x-proxy-cache: HIT
# x-rate-limit: NORMAL_CACHE
# referrer-policy: unsafe-url
# server: nfront
# connection: close
#
#
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# 	<meta charset="UTF-8">
# 	<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<meta http-equiv="X-UA-Compatible" content="requiresActiveX=true">
# 	<meta name="viewport" content="width=1080px,maximum-scale=2.0,minimum-scale=0.4,user-scalable=yes">
#
#
# 			<meta property="me:feed:serviceId" content="sports"/>
# 			<meta property="me:feed:feedGroupId" content="sports"/>
# 			<meta property="me:feed:feedId" content=""/>
# 			<meta property="me:feed:feedName" content=""/>
# 			<meta property="me:feed:feedGroupName" content=""/>
# 			<meta property="me:feed:url" content=""/>
# 			<meta property="og:update_time" content="20230706163301"/>
# 			<meta property="article:contentLocation:name" content=""/>
# 			<meta property="article:contentLocation:url" content=""/>
#
# 		<meta property="og:type"        content="article"/>
# 		<meta property="og:image"       content="https://imgnews.pstatic.net/image/311/2023/07/06/0001612891_001_20230706163301732.jpg" />
# 		<meta property="og:title"       content="&quot;김민재 뮌헨행 완료, 끝났다!!…메디컬 뒤 계약서 '사인'&quot;→로마노 'Here we go confirmed' 선언"/>
# 		<meta property="og:description" content="(엑스포츠뉴스 나승우 기자) 끝났다. 김민재의 독일 바이에른 뮌헨 이적이 끝났다.세계적인 이적시장 전문가가 김민재의 뮌헨 입단을 확신했다. 더 이상의 변수는 없다. &#39;레바뮌 트리오&#39;로 불리며 세계 3대 명문 중 하나로 자리매김한 뮌헨에 한국인 수비수가 간다.이적시장 전문가 파브리치오 로마노가 이를 확인했다...."/>
# 		<meta property="og:url"         content="https://sports.news.naver.com/news?oid=311&aid=0001612891"/>
# 		<meta property="og:article:author" content="네이버 스포츠 | 엑스포츠뉴스"/>
# 		<meta property="og:article:author:url" content="https://sports.news.naver.com"/>
# 		<meta property="og:article:thumbnailUrl" content="https://imgnews.pstatic.net/image/sports/common/naverme/image-sports.png"/>
# 		<meta name="napp-site-analysis" content="gdid=880005B6_000000000000000001612891,service=sports,collection=news,section=107"/>
#
#
#
#
# 			<title>"김민재 뮌헨행 완료, 끝났다!!…메디컬 뒤 계약서 '사인'"→로마노 'Here we go confirmed' 선언</title>
#
#
# 	<link rel="shortcut icon" href="/favicon.ico?v=20140331" otype="image/x-icon">
# 	<link rel="apple-touch-icon" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS6_57X57_iphone3.png">
# 	<link rel="apple-touch-icon" sizes="76x76" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS7_76X76_ipad.png">
# 	<link rel="apple-touch-icon" sizes="120x120" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS7_120X120_iphone.png">
# 	<link rel="apple-touch-icon" sizes="152x152" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS7_152X152_ipad_retina.png">
# 	<link rel="apple-touch-icon" sizes="167x167" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS_167X167_iPadPro.png"> <!-- 레티나 패드 -->
# 	<link rel="apple-touch-icon" sizes="180x180" href="https://imgsports.pstatic.net/images/mobile/favicon_20180622/ios/iOS_180X180_iPhone.png"> <!-- 레티나 패드 -->
# 	<content tag="css">
# 		<link rel='stylesheet' type='text/css' href='https://ssl.pstatic.net/static.sports/resources/pc/292929/66/298/665600/css/generated/nsportsCss.css'>
#
# 		<link rel='stylesheet' type='text/css' href='https://ssl.pstatic.net/static.sports/resources/pc/292929/66/298/665600/css/generated/newsEndOg.css'>
#
# 	</content>
# 	<script type='text/javascript' src='https://ssl.pstatic.net/static.sports/resources/pc/292929/66/298/665600/js/generated/newsCommon.js' charset='UTF-8'></script>
#
#
#
# <script>
# 	try {
# 		var deployPhase = 'release';
# 		if (deployPhase === 'release') {
# 			JEagleEyeClient.attachOnError();
#
# 		} else if (deployPhase === 'dev') {
# 			JEagleEyeClient.setDebugOnly(true);
# 			JEagleEyeClient.attachOnError();
#
# 		} else {
# 			// local
# 			JEagleEyeClient.attachOnError();
# 		}
# 	} catch (e) {
# 		console.log(e);
# 	}
# </script>
#
# 	<script type="text/javascript" language="javascript">
# 		var sports_category="";
# 		var ccsrv="cc.naver.com";
# 		var nsc = "sports.worldfootball";
# 		var gdid = "880005B6_000000000000000001612891";
# 	</script>
# </head>
# <body>
#
# <div id="u_skip">
# 	<a href="#lnb_main_s

# %%
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key=f5eef3421c602c6cb7ea224104795888&movieCd=20124079"

try:
    res = req.urlopen(url)
    contents = res.read().decode('utf-8')
except Exception as e:
    print(e)
else:
    with open("./movie.txt","w",encoding="utf-8") as f:
        f.write(contents)

# %%
from urllib.parse import urlencode

url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&"

param = {"query":"축구"}

url += urlencode(param)

try:
    res = req.urlopen(url)
    contents = res.read().decode('utf-8')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# Date: Thu, 06 Jul 2023 08:38:35 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Vary: Accept-Encoding
# Set-Cookie: page_uid=i6i9Awp0YidssgQQTnCssssst/K-137441; path=/; domain=.naver.com
# Set-Cookie: _naver_usersession_=mrp7tXP6BzbSZII9MSMKng==; path=/; expires=Thu, 06-Jul-23 08:43:35 GMT; domain=.naver.com
# X-Frame-Options: SAMEORIGIN
# X-XSS-Protection: 1; report=/p/er/post/xss
# Cache-Control: no-cache, no-store, must-revalidate, max-age=0
# Pragma: no-cache
# Set-Cookie: nx_ssl=2; Domain=.naver.com; Path=/; Expires=Sat, 05-Aug-2023 08:38:35 GMT;
# Referrer-Policy: unsafe-url
# Vary: Accept-Encoding
# Server: nxg
# Accept-CH: Sec-CH-UA, Sec-CH-UA-Arch, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version-List, Sec-CH-UA-Mobile, Sec-CH-UA-Model, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA-WoW64
#
#
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="축구 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'축구'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'축구'의 네이버 통합검색 결과입니다."> <title>축구 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230706.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_230629.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].appendChild(scrs[script].domscript); }; })() ; var nx_js_defer_load = (function() { var info = {} ; return function(scrname, callback, t) { var nx_load_once = (function() { return function(scrname) { if (info[scrname].t > 0) setTimeout(function() { _nx_js_load(scrname, info[scrname].callback) ; }, t) ; else _nx_js_load(scrname, info[scrname].callback) ; } ; })(); if (t < 0) t = 0 ; if (info[scrname]) { n = info[scrname].length; for (var i = 0; i < n; i++) { if (info[scrname][i] == callback) return ; } if (t < info[scrname].t) info[scrname].t = t ; } else { info[scrname] = {} ; info[scrname].callback = [] ; info[scrname].t = t ; jindo.$Fn(function() { nx_load_once(scrname) ; }).attach(window, "load") ; } info[scrname].callback.push(callback) ; }; })(); function nx_js_lazyload(scripts, onload, is_serial) { if (!(scripts instanceof Array)) { scripts = [scripts]; } if (is_serial) { function load_next() { if (scripts.length == 0) { onload(); return; } _nx_js_load( scripts.shift(), load_next ) ; } load_next(); } else { var load_check = function() { var num_js = scripts.length; return function() {

# %%
# fake-useragent: useragent 생성
# 파이썬으로 크롤링 시 상대 서버는 파이썬 프로그램으로 요청이 들어온다는 걸 알게 됨
# 요청을 브라우저로 하고 있다고 속여내는 방법

# %%
from fake_useragent import UserAgent

userAgent = UserAgent()

print(userAgent.ie)
print(userAgent.chrome)
print(userAgent.random)
# Out:
# Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 6.1; Trident/6.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; .NET4.0C; .NET4.0E)
# Mozilla/5.0 (X11; Linux i686) AppleWebKit/534.30 (KHTML, like Gecko) Slackware/Chrome/12.0.742.100 Safari/534.30
# Mozilla/5.0 (Windows NT 5.2) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.813.0 Safari/535.1

# %%
from fake_useragent import UserAgent
import urllib.request as req
import json
import csv

kosdaq = []

try:
    userAgent = UserAgent()
    url = "https://finance.daum.net/api/search/ranks?limit=10"

    headers = {
        "user-agent": userAgent.random,
        "referer": "https://finance.daum.net/"
    }

    request_url = req.Request(url, headers=headers) # headers 정보가 없으면 파이썬에서 들어간 것으로 출력됨으로 눈속임을 위해 headers 넣어준다.
    info = req.urlopen(request_url)
    res = info.read().decode("utf-8")
except Exception as e:
    print(e)
else:
    # print(res)
    data = json.loads(res)["data"]

    for item in data:
        print("순위: {}, 금액: {}, 회사명: {}".format(item["rank"], item["tradePrice"], item["name"]))

        kosdaq.append(item)

        with open("./finance.csv", "w", newline="") as f:
            output = csv.writer(f)
            output.writerow(kosdaq[0].keys())

            for row in kosdaq:
                output.writerow(row.values())
# Out:
# 순위: 1, 금액: 50500, 회사명: 카카오
# 순위: 2, 금액: 70200, 회사명: 삼성전자
# 순위: 3, 금액: 78800, 회사명: 금양
# 순위: 4, 금액: 945000, 회사명: 에코프로
# 순위: 5, 금액: 56500, 회사명: 삼성중공우
# 순위: 6, 금액: 3705, 회사명: 삼부토건
# 순위: 7, 금액: 28760, 회사명: KODEX 2차전지산업
# 순위: 8, 금액: 17240, 회사명: 두산에너빌리티
# 순위: 9, 금액: 31240, 회사명: KODEX 반도체
# 순위: 10, 금액: 6140, 회사명: 시큐센
